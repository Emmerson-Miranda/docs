# %% [markdown]
# # Description
#
# Examples how to run bash commands from Jupiter Notebook

# %%
# %%sh
# echo "hello"
# echo "world"

# %%
# %%sh
# echo $HOME
# Out:
# /Users/emmersonmiranda

# %%
# %%sh
# du -sh ./* | sort -h
# Out:
#  80K	./00_hello_world.ipynb

# %%
# %%sh
# ls -l
# Out:
# total 8
# -rw-r--r--  1 emmersonmiranda  staff  1940 Nov 19 22:02 00_hello_world.ipynb

# %% [markdown]
# ## I can use exclamation mark to execute bash commands
#
# ! always open a new sub process

# %%
# !echo $$
# Out:
# 35144

# %%
# !echo $$
# Out:
# 35156

# %%
# !ls -l
# Out:
# total 8
# -rw-r--r--  1 emmersonmiranda  staff  1940 Nov 19 22:02 00_hello_world.ipynb

# %%
output = !ls -l
output
# Out:
# ['total 8',
#  '-rw-r--r--  1 emmersonmiranda  staff  1940 Nov 19 22:02 00_hello_world.ipynb']

# %% [markdown]
# ## variables

# %%
# !echo $MYVAR

# %%
# !export MYVAR="Hello World"

# %%
# !echo $MYVAR

# %%
# %%sh
# export MYVAR="Hello World"
# echo $MYVAR
# Out:
# Hello World
